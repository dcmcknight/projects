# %% [markdown]
# # Pandas

# %%
import pandas as pd
import seaborn as sns
import numpy as np
np.warnings.filterwarnings('ignore')
sns.set()

df = pd.read_csv('/Users/drewmcknight1/Desktop/MISY630/Fall 2020 Course Files/Assignments/responses.csv')
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3      1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# ...

# %%
df2 = df[['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country', 'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock']].copy()
df2.rename(columns={'Metal or Hardrock': 'HardRock'}, inplace=True)
df2.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  HardRock
# 0      1.0  5.0   5.0       1.0
# 1      2.0  3.0   5.0       4.0
# 2      5.0  3.0   5.0       3.0
# 3      1.0  2.0   2.0       1.0
# 4      3.0  5.0   3.0       1.0

# %%
df2.loc[df.Gender == 'male', 'GenderCode'] = 1
df2.loc[df.Gender == 'female', 'GenderCode'] = 0
df2.head(8)
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
# 5    5.0                       3.0    2.0   3.0      2.0              3.0
# 6    5.0                       5.0    5.0   3.0      1.0              2.0
# 7    5.0                       3.0    3.0   2.0      1.0              2.0
#
#    Musical  Pop  Rock  HardRock  GenderCode
# 0      1.0  5.0   5.0       1.0         0.0
# 1      2.0  3.0   5.0       4.0         0.0
# 2      5.0  3.0   5.0       3.0         0.0
# 3      1.0  2.0   2.0       1.0         0.0
# 4      3.0  5.0   3.0       1.0         0.0
# ...

# %%
df2['HardRock'].groupby(df2['GenderCode']).mean()
# Out:
# GenderCode
# 0.0    2.160473
# 1.0    2.639024
# Name: HardRock, dtype: float64

# %% [markdown]
# # Visualizations

# %%
sns.distplot(df2.Music)

# %% [markdown]
# The above indicates that the majority of students gave a response of 5 for the Music category and is skewed to the right

# %%
sns.scatterplot(x="Folk", y="Rock", data=df2)

# %% [markdown]
# This indicates that there is no relationship between folk and rock preferences. They are independent of each other.

# %%
sns.boxplot(df2.Country)

# %% [markdown]
# * For country, the middle 50% is evenly distributed from the median of 2
# * the 1st quartile (25%) has a value of 1
# * the 3rd quartile (75%) a value of 3
# * max value of 5

# %% [markdown]
# # Descriptive Stats

# %%
df3 = df[['Gender', 'Height', 'Weight', 'Age']].copy()
df3.isnull().sum()
# Out:
# Gender     6
# Height    20
# Weight    20
# Age        7
# dtype: int64

# %% [markdown]
# The above shows the sum of null values for each category.

# %%
df3.dropna()
# Out:
#       Gender  Height  Weight   Age
# 0     female   163.0    48.0  20.0
# 1     female   163.0    58.0  19.0
# 2     female   176.0    67.0  20.0
# 3     female   172.0    59.0  22.0
# 4     female   170.0    59.0  20.0
# 5       male   186.0    77.0  20.0
# 6     female   177.0    50.0  20.0
# 7       male   184.0    90.0  19.0
# 8     female   166.0    55.0  18.0
# 9     female   174.0    60.0  19.0
# 10    female   175.0    60.0  19.0
# 11    female   176.0    60.0  17.0
# 12    female   168.0    55.0  24.0
# 13    female   165.0    55.0  19.0
# 14    female   175.0    57.0  22.0
# 15      male   177.0    77.0  18.0
# 16    female   175.0    65.0  19.0
# 17    female   168.0    65.0  20.0
# 18      male   181.0    78.0  18.0
# 19      male   188.0    90.0  18.0
# 20      male   186.0    77.0  20.0
# 21      male   186.0    85.0  24.0
# 22    female   167.0    70.0  22.0
# 23    female   168.0    54.0  20.0
# 24    female   167.0    51.0  19.0
# 25    female   170.0    56.0  20.0
# ...

# %%
df3.Weight.median()
# Out:
# 64.0

# %%
df3.Weight.mean()
# Out:
# 66.40505050505051

# %%
df3.Weight.mode()
# Out:
# 0    60.0
# dtype: float64

# %%
df3['Weight'].groupby(df3['Gender']).mean()
# Out:
# Gender
# female    58.963793
# male      77.088889
# Name: Weight, dtype: float64

# %% [markdown]
# As expected, the average weight for men is higher than the average for women

# %%
df3.Gender.value_counts()
# Out:
# female    593
# male      411
# Name: Gender, dtype: int64

# %%
maledf = df3.loc[df3.Gender == 'male'] #checking if values are valid
femaledf = df3.loc[df3.Gender == 'female']
print('Gender:\n{0}\n{1}'.format(len(maledf), len(femaledf)))
# Out:
# Gender:
# 411
# 593

# %% [markdown]
# majority of responses are a 3 with 321, followed by 4 with 235, 2 with 215, 5 with 141, and 1 with 94

# %% [markdown]
# # List and Dictionaries

# %%
my_dict = {}
my_dict['Antonio'] = 26
my_dict['Brandon'] = 25
my_dict['Sterling'] = 26
my_dict['Jarvis'] = 24
my_dict['Mariela'] = 23
my_dict
# Out:
# {'Antonio': 26, 'Brandon': 25, 'Jarvis': 24, 'Mariela': 23, 'Sterling': 26}

# %%
data = {
    'Antonio': [89, 75, 93, 98],
    'Brandon': [45, 67, 88, 91],
    'Sterling': [55, 99, 100, 65],
    'Jarvis': [77, 88, 87, 90],
    'Mariela': [90,88, 65, 45]
         }
print(sum(data['Antonio'])/len(data['Antonio']))
print(sum(data['Brandon'])/len(data['Brandon']))
print(sum(data['Sterling'])/len(data['Sterling']))
print(sum(data['Jarvis'])/len(data['Jarvis']))
print(sum(data['Mariela'])/len(data['Mariela']))
# Out:
# 88.75
# 72.75
# 79.75
# 85.5
# 72.0

# %%
def calcAverage(scores):
    name = input('Enter name: ')
    average = sum(scores[name])/len(scores[name])
    return '{:s}\'s final score is {:.2f}%'.format(name, average)

print(calcAverage(data))
# Out:
# Enter name:  Mariela
# Mariela's final score is 72.00%

# %% [markdown]
# ## Reflection:

# %% [markdown]
# * I first create a dictionary with a list of scores associated to a particular student named 'data'
# * I define a function that accepts a dictionary as a parameter named 'scores'
# * created a variable called 'name' which represents the key in the dictionary
# * I calculate the average by taking the sum of the scores (i.e. value of scores dict) for a specific student (i.e. key of scores dict) and divide it by the length of the scores list (i.e. value of scores dict).
# * The function then returns the inputted name and average grade for that student
